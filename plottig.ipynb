# %%
print("hello world  ")
# Out:
# hello world

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# This shows: Frequency of values in a dataset and also how data is distibuted
# Kernel Density Estimate (KDE) curve on top of your histogram bars.
#  
import matplotlib.pyplot as plt
import seaborn as sns
data = [10,33.12,7,9,12,15,20,25,30,35]
sns.histplot(data, bins=6, kde=True)
plt.title("Histogram with KDE")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
# This creates a smooth distibution curve instead of bars
sns .kdeplot(data,fill = True)
plt.title("KDE Plot")
plt.show()

# %%
median = np.median(data)
print("Median:", median)
quartiles = np.percentile(data, [25, 50, 75])
print("Quartiles:", quartiles)
outliers = [x for x in data if x < quartiles[0] or x > quartiles[2]]
print("Outliers:", outliers)
sns.boxplot(data)
plt.title("Box Plot")
# Out:
# Median: 17.5
# Quartiles: [10.5  17.5  28.75]
# Outliers: [10, 33.12, 7, 9, 30, 35]
# Text(0.5, 1.0, 'Box Plot')

# %%
# Regression Visualization in seaborn
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
data = pd.DataFrame({"hours_studied": [1, 2, 3, 4, 5], "exam_score": [50, 60, 70, 80, 90]})
sns.regplot(x="hours_studied", y="exam_score", data=data)
plt.title("Regression Plot")
plt.show()

# %%
sns.lmplot(x="hours_studied", y="exam_score", data=data)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
data = {
    "hours":[1,2,3,4,5],
    "score":[50,55,65,70,80]
}

df = pd.DataFrame(data)

# %%
X = df[['hours']]
y = df['score']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[6]])
print(prediction)
# Out:
# [86.5]
# c:\Users\pinki\OneDrive\Desktop\pinki file\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Visualize the regression line
plt.scatter(X, y)
plt.plot(X, model.predict(X))
plt.xlabel("Study Hours")
plt.ylabel("Score")
plt.show()
